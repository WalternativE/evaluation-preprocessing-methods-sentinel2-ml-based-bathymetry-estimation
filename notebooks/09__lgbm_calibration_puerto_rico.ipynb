# %% [markdown]
# # Satellite Derived Bathymetry Using a Tuned LightGBM Model for the Puerto Rico Area of Interest
#
# Author: Gregor Beyerle
#
# Date: 2022-06-21
#
# ## Overview
#
# This notebook contains the steps taken to perform SDB estimations for the L2A, L1C, and Acolite data products for this AOI. This includes:
#
# - Loading the prepared data
# - Setting up training, validation and test data splits
# - Performing hyper parameter and model tuning using Optuna
# - Evaluating the model
#
# In contrast to the Stumpf Log-Ratio Method which is based on empirical observations and evaluations tuning and fitting a LightGBM model for this use case is solely based on data driven methods.

# %%
import os
import sys
import dotenv

from IPython.utils import io

import eolearn
from eolearn.core import (
    FeatureType,
    linearly_connect_tasks,
    EOWorkflow,
    OutputTask,
    LoadTask,
)
from eolearn.ml_tools import TrainTestSplitTask

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from lightgbm import log_evaluation, early_stopping
import optuna.integration.lightgbm as lgb
from sklearn.model_selection import train_test_split

import dalex as dx

# %% [markdown]
# This notebook uses functionality of both the `eolearn_extras` module as well as the `sdb_utils` module. It is important to add the relative location of the repository's root directory to the `sys.path` and import `eolearn_extras` before `sdb_utils` as some functions in this module reference `eolearn_extras`.

# %%
root_dir = os.path.abspath('../')
if not root_dir in sys.path: sys.path.append(root_dir)

import eolearn_extras as eolx
from sdb_utils.ml_utils import (
    get_X_y_for_split,
    SplitType,
    create_sdb_estimation,
    get_masked_map,
    create_train_val_set,
    write_optuna_capture_to_logs,
)

# %% [markdown]
# The data for this project can - depending on whether you work with the complete dataset or only the preprocessed data - be roughly 13 GB on disk. This makes it necessary to distribute data individually from the repository and therefore the location of the data root directory might differ from setup to setup. This repository uses a `.env` file to configure the individual data root directory location. You need to add the `.env` file to your `notebooks` directory and add a line containing the needed information as a line following the pattern `data_root=<path-to-your-data-root>` in order for this notebook to work correctly.

# %%
dotenv.load_dotenv()
data_root_path = os.environ.get('data_root')

# %% [markdown]
# We already prepared the needed data for this AOI in previous notebooks. The first step of the workflow for preparing the train-test-split is to load it from disk.

# %%
puerto_rico_eop_path = os.path.abspath(
    os.path.join(data_root_path, 'eopatches', 'puerto_rico_sentinel_merged')
)
load_puerto_rico_eop = LoadTask(puerto_rico_eop_path)

# %% [markdown]
# The eo-learn framework includes a `TrainTestSplitTask` which can be used to create a mask with an arbitrary amount of numerical class (e.g. train, validation and test) labels. For this AOI I decided to use 5% of all possible pixels for training and validation, holding back 95% of the remaining pixels for the final evaluation. I did not want to use more samples because with the AOI not offering a very high degree of variance and the spatial resolution being relatively high, the danger of overfitting appears to be especially pressing. Also, even if in reality a field survey is unlikely to perform a uniform sampling over the whole AOI, I would like to perform an analysis that has some use for people that only have the possibility to survey a limited amount of point tracks when collecting their own calibration data.

# %%
data_mask_feature = (FeatureType.MASK_TIMELESS, 'bathy_data_mask')
train_test_mask_feature = (FeatureType.MASK_TIMELESS, 'train_test_split')

train_test_split_task = TrainTestSplitTask(
    input_feature=data_mask_feature,
    output_feature=train_test_mask_feature,
    bins=[0.025, 0.05],
    split_type=eolearn.ml_tools.train_test_split.TrainTestSplitType.PER_PIXEL,
)

# %% [markdown]
# The `TrainTestSplitTask` does not itself take an argument for masking out "uninteresting" pixels. Also, it does produce only one mask for all classes, which is - at times - cumbersome to use. I use the `AddValidTrainTestMasks` to combine the bathymetry data mask and the pixel locations of each split to their own masks.

# %%
valid_train_test_data_mask_task = eolx.ml_util.AddValidTrainTestMasks(
    train_test_maks_feature=train_test_mask_feature,
    valid_data_mask_feature=data_mask_feature
)

# %% [markdown]
# The workflow for performing this preparation is comparatively simple as seen in the dependency graph below.

# %%
tt_wf_output_label = 'tt_wf_output'
output_task = OutputTask(tt_wf_output_label)

nodes = linearly_connect_tasks(
    load_puerto_rico_eop,
    train_test_split_task,
    valid_train_test_data_mask_task,
    output_task,
)
read_merge_wf = EOWorkflow(nodes)

read_merge_wf.dependency_graph()

# %% [markdown]
# Without configuring a random seed to the `TrainTestSplitTask` the pixels in each split would differ with each execution. While this should not impact the analysis it would impair others to repeat the analysis and come to the exact same results. The `seed` argument has to be configured at execution time. To do this in the context of a workflow rather than a simple task execution we can find the `EONode` reference in the list of nodes which was implicitly created for us when we executed the `linearly_connected_tasks` function.
#
# After executing the workflow we can see that we now have the required masks as well as some additional information in the `meta_info` that helps to gain an intuition for the magnitude of each supported split.

# %%
train_test_split_ref = [node for node in nodes if node.name == 'TrainTestSplitTask'][0]
read_merge_wf_res = read_merge_wf.execute(
    input_kwargs={
        train_test_split_ref: {'seed': 42}
    }
)

train_test_eop = read_merge_wf_res.outputs[tt_wf_output_label]
train_test_eop
# Out:
# EOPatch(
#   data={
#     L1C_data: numpy.ndarray(shape=(1, 319, 544, 13), dtype=float32)
#     L2A_data: numpy.ndarray(shape=(1, 319, 544, 12), dtype=float32)
#     L2R_data: numpy.ndarray(shape=(1, 319, 544, 11), dtype=float32)
#   }
#   data_timeless={
#     bathy_data: numpy.ndarray(shape=(319, 544, 1), dtype=float32)
#   }
#   mask_timeless={
#     bathy_data_mask: numpy.ndarray(shape=(319, 544, 1), dtype=uint8)
#     test_split_valid: numpy.ndarray(shape=(319, 544, 1), dtype=int32)
#     train_split_valid: numpy.ndarray(shape=(319, 544, 1), dtype=int32)
#     train_test_split: numpy.ndarray(shape=(319, 544, 1), dtype=int64)
#     validation_split_valid: numpy.ndarray(shape=(319, 544, 1), dtype=int32)
#   }
#   meta_info={
#     test_count: 164983
#     test_perc: 0.9507133966439241
#     train_count: 4253
#     train_perc: 0.02450788309054029
#     validation_count: 4300
#     validation_perc: 0.02477872026553568
#   }
#   bbox=BBox(((686070.726989808, 2007089.913413469), (691510.726989808, 2010279.913413469)), crs=CRS('32619'))
#   timestamp=[datetime.datetime(2021, 5, 2, 15, 7, 19), datetime.datetime(2021, 5, 2, 15, 7, 48)]
# )

# %% [markdown]
# To get a better idea how the samples are distributed per split we can have a look at the created maps. Below we can see the split for training data as an example.

# %%
eolx.visualization.plot_single_band(train_test_eop, (FeatureType.MASK_TIMELESS, 'train_split_valid'), colorbar=False, stretch=False)
plt.show()

# %% [markdown]
# ## Performing SDB on the Basis of L2A Data
#
# In contrast to the empirical Stumpf Log-Ratio model where we can follow an intuitive formula to prepare the most significant band information and use that to fit a linear regression model without any hyper parameters there are more elements to calibrate in a regression problem when using LightGBM. LightGBM is a machine learning library that allows us to build models on the basis of gradient boosted trees. On this basis we can model non-linear relationships and effects between different attributes while also working with large amount of data (Ke et al., 2017). To get the best results I plan to use the Optuna hyperparameter optimization framework (Akiba et al., 2019) to choose the best combination of hyper parameters for a given AOI.
#
# LightGBM works best with `DataSet` objects that allow very efficient access for training a large amount of decision trees.

# %%
(train_ds, val_ds) = create_train_val_set(train_test_eop, (FeatureType.DATA, 'L2A_data'))

# %% [markdown]
# I use the `optuna.integration.lightgbm` module as a drop-in replacement for the standard LightGBM python module. This has the positive effect of full Optuna integration while still being very close to the standard LightGBM API.
#
# I configure the model for a regression task using the mean squared error as the the error metric. I set a random seed because LightGBM uses randomness in the process of building the gradient boosted trees and I would like to deterministically produce the same results for each time this experiment is rerun.
#
# In theory a LightGBM model could train for an arbitrarily large amount of iterations. When doing that on a training data set the results will - with enough time - most likely approach optimal scores for this exact set of data, leading to severe overfitting. I configure an early stopping callback that stops the training of a model if there hasn't been any improvement on the validation data set (improvements in the training data set are ignored) for 100 iterations.
#
# As Optuna and LightGBM can get rather verbose with their outputs I configure a Jupyter Notebook capture for outputs that might still be interesting for debugging and optimization diagnosis.

# %%
params = {
    'objective': 'regression',
    'metric': 'mean_squared_error',
    'seed': 42,
}

with io.capture_output() as capture:
    model_l2a = lgb.train(
        params,
        train_ds,
        valid_sets=val_ds,
        callbacks=[early_stopping(100), log_evaluation(100)],
        optuna_seed=42,
    )

write_optuna_capture_to_logs('../optuna_logs', capture)
# Out:
# [I 2022-06-21 23:07:13,441] A new study created in memory with name: no-name-a3b2c910-91c0-42ea-a1c7-59743f856002
# [I 2022-06-21 23:07:13,723] Trial 0 finished with value: 0.9506021979676467 and parameters: {'feature_fraction': 0.6}. Best is trial 0 with value: 0.9506021979676467.
# [I 2022-06-21 23:07:14,007] Trial 1 finished with value: 0.9506021979676467 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.9506021979676467.
# [I 2022-06-21 23:07:14,217] Trial 2 finished with value: 0.9506021979676467 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.9506021979676467.
# [I 2022-06-21 23:07:14,445] Trial 3 finished with value: 0.9268286095738666 and parameters: {'feature_fraction': 1.0}. Best is trial 3 with value: 0.9268286095738666.
# [I 2022-06-21 23:07:14,618] Trial 4 finished with value: 0.9268286095738666 and parameters: {'feature_fraction': 0.5}. Best is trial 3 with value: 0.9268286095738666.
# [I 2022-06-21 23:07:14,866] Trial 5 finished with value: 0.9268286095738666 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 3 with value: 0.9268286095738666.
# [I 2022-06-21 23:07:15,106] Trial 6 finished with value: 0.9268286095738666 and parameters: {'feature_fraction': 0.8}. Best is trial 3 with value: 0.9268286095738666.
# [I 2022-06-21 23:07:15,645] Trial 7 finished with value: 0.9268286095738666 and parameters: {'num_leaves': 97}. Best is trial 7 with value: 0.9268286095738666.
# [I 2022-06-21 23:07:16,203] Trial 8 finished with value: 0.922841595798381 and parameters: {'num_leaves': 244}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:16,707] Trial 9 finished with value: 0.922841595798381 and parameters: {'num_leaves': 188}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:17,142] Trial 10 finished with value: 0.922841595798381 and parameters: {'num_leaves': 154}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:17,325] Trial 11 finished with value: 0.922841595798381 and parameters: {'num_leaves': 41}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:17,495] Trial 12 finished with value: 0.922841595798381 and parameters: {'num_leaves': 41}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:17,585] Trial 13 finished with value: 0.922841595798381 and parameters: {'num_leaves': 16}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:18,185] Trial 14 finished with value: 0.922841595798381 and parameters: {'num_leaves': 222}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:18,637] Trial 15 finished with value: 0.922841595798381 and parameters: {'num_leaves': 155}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:19,136] Trial 16 finished with value: 0.922841595798381 and parameters: {'num_leaves': 182}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:19,729] Trial 17 finished with value: 0.922841595798381 and parameters: {'num_leaves': 251}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:20,209] Trial 18 finished with value: 0.922841595798381 and parameters: {'num_leaves': 208}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:20,787] Trial 19 finished with value: 0.922841595798381 and parameters: {'num_leaves': 251}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:21,223] Trial 20 finished with value: 0.922841595798381 and parameters: {'num_leaves': 118}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:21,696] Trial 21 finished with value: 0.922841595798381 and parameters: {'num_leaves': 208}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:22,190] Trial 22 finished with value: 0.922841595798381 and parameters: {'num_leaves': 177}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:22,661] Trial 23 finished with value: 0.922841595798381 and parameters: {'num_leaves': 228}. Best is trial 8 with value: 0.922841595798381.
# [I 2022-06-21 23:07:23,077] Trial 24 finished with value: 0.9221899547157066 and parameters: {'num_leaves': 143}. Best is trial 24 with value: 0.9221899547157066.
# [I 2022-06-21 23:07:23,351] Trial 25 finished with value: 0.9221899547157066 and parameters: {'num_leaves': 87}. Best is trial 24 with value: 0.9221899547157066.
# [I 2022-06-21 23:07:23,657] Trial 26 finished with value: 0.9221899547157066 and parameters: {'num_leaves': 97}. Best is trial 24 with value: 0.9221899547157066.
# [I 2022-06-21 23:07:24,048] Trial 27 finished with value: 0.9221899547157066 and parameters: {'bagging_fraction': 0.624724071308792, 'bagging_freq': 7}. Best is trial 27 with value: 0.9221899547157066.
# [I 2022-06-21 23:07:24,508] Trial 28 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.8391963650875751, 'bagging_freq': 5}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:24,758] Trial 29 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.49361118426561795, 'bagging_freq': 2}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:25,007] Trial 30 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.4348501673009778, 'bagging_freq': 7}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:25,416] Trial 31 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.7606690070465265, 'bagging_freq': 5}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:25,660] Trial 32 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.41235069657750206, 'bagging_freq': 7}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:26,126] Trial 33 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.8994655844810855, 'bagging_freq': 2}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:26,392] Trial 34 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.5090949803244422, 'bagging_freq': 2}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:26,706] Trial 35 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.5825453457760269, 'bagging_freq': 4}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:27,039] Trial 36 finished with value: 0.9121995792032759 and parameters: {'bagging_fraction': 0.6591670111857015, 'bagging_freq': 3}. Best is trial 28 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:27,553] Trial 37 finished with value: 0.9121995792032759 and parameters: {'feature_fraction': 0.92}. Best is trial 37 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:28,058] Trial 38 finished with value: 0.9121995792032759 and parameters: {'feature_fraction': 0.9840000000000001}. Best is trial 37 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:28,495] Trial 39 finished with value: 0.9121995792032759 and parameters: {'feature_fraction': 0.9520000000000001}. Best is trial 37 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:29,012] Trial 40 finished with value: 0.9121995792032759 and parameters: {'lambda_l1': 2.348881295853308e-05, 'lambda_l2': 3.6010467344475403}. Best is trial 40 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:29,466] Trial 41 finished with value: 0.9121995792032759 and parameters: {'lambda_l1': 0.038720902953704193, 'lambda_l2': 0.0024430162614261413}. Best is trial 40 with value: 0.9121995792032759.
# [I 2022-06-21 23:07:29,959] Trial 42 finished with value: 0.9121995790523415 and parameters: {'lambda_l1': 2.5361081166471375e-07, 'lambda_l2': 2.5348407664333426e-07}. Best is trial 42 with value: 0.9121995790523415.
# [I 2022-06-21 23:07:30,416] Trial 43 finished with value: 0.9121995790523415 and parameters: {'lambda_l1': 3.3323645788192616e-08, 'lambda_l2': 0.6245760287469893}. Best is trial 42 with value: 0.9121995790523415.
# [I 2022-06-21 23:07:30,877] Trial 44 finished with value: 0.9121995790523415 and parameters: {'lambda_l1': 0.002570603566117598, 'lambda_l2': 0.023585940584142682}. Best is trial 42 with value: 0.9121995790523415.
# [I 2022-06-21 23:07:31,292] Trial 45 finished with value: 0.9121995790523415 and parameters: {'lambda_l1': 1.5320059381854043e-08, 'lambda_l2': 5.360294728728285}. Best is trial 42 with value: 0.9121995790523415.
# [I 2022-06-21 23:07:31,753] Trial 46 finished with value: 0.9121995790523415 and parameters: {'lambda_l1': 0.31044435499483225, 'lambda_l2': 8.148018307012941e-07}. Best is trial 42 with value: 0.9121995790523415.
# [I 2022-06-21 23:07:32,202] Trial 47 finished with value: 0.9121995789026696 and parameters: {'lambda_l1': 4.329370014459266e-07, 'lambda_l2': 4.4734294104626844e-07}. Best is trial 47 with value: 0.9121995789026696.
# [I 2022-06-21 23:07:32,654] Trial 48 finished with value: 0.9121995789026696 and parameters: {'lambda_l1': 5.472429642032198e-06, 'lambda_l2': 0.00052821153945323}. Best is trial 47 with value: 0.9121995789026696.
# [I 2022-06-21 23:07:33,085] Trial 49 finished with value: 0.912199554414684 and parameters: {'lambda_l1': 7.71800699380605e-05, 'lambda_l2': 4.17890272377219e-06}. Best is trial 49 with value: 0.912199554414684.
# [I 2022-06-21 23:07:33,537] Trial 50 finished with value: 0.912199554414684 and parameters: {'lambda_l1': 0.0004944915061688625, 'lambda_l2': 1.755150973656557e-05}. Best is trial 49 with value: 0.912199554414684.
# [I 2022-06-21 23:07:33,996] Trial 51 finished with value: 0.912199554414684 and parameters: {'lambda_l1': 0.000459551809456671, 'lambda_l2': 1.3232991168593193e-05}. Best is trial 49 with value: 0.912199554414684.
# [I 2022-06-21 23:07:34,456] Trial 52 finished with value: 0.9111286330406074 and parameters: {'lambda_l1': 0.005764962972197511, 'lambda_l2': 2.806512832601289e-05}. Best is trial 52 with value: 0.9111286330406074.
# [I 2022-06-21 23:07:34,859] Trial 53 finished with value: 0.9085600265333402 and parameters: {'lambda_l1': 3.3760383909096228, 'lambda_l2': 1.4786066213553811e-08}. Best is trial 53 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:35,288] Trial 54 finished with value: 0.9085600265333402 and parameters: {'lambda_l1': 3.3316309468938208, 'lambda_l2': 1.1176227539582341e-08}. Best is trial 53 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:35,579] Trial 55 finished with value: 0.9085600265333402 and parameters: {'lambda_l1': 8.542110184337343, 'lambda_l2': 1.1972114612206646e-08}. Best is trial 53 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:35,976] Trial 56 finished with value: 0.9085600265333402 and parameters: {'lambda_l1': 3.8101280528613053, 'lambda_l2': 1.7764941414367e-08}. Best is trial 53 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:36,646] Trial 57 finished with value: 0.9085600265333402 and parameters: {'lambda_l1': 0.41055567008844696, 'lambda_l2': 6.541881005277658e-08}. Best is trial 53 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:37,210] Trial 58 finished with value: 0.9085600265333402 and parameters: {'lambda_l1': 0.18875075955046108, 'lambda_l2': 1.0431289263389712e-07}. Best is trial 53 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:37,819] Trial 59 finished with value: 0.9085600265333402 and parameters: {'lambda_l1': 0.10124435578855118, 'lambda_l2': 0.00010624533535603656}. Best is trial 53 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:38,415] Trial 60 finished with value: 0.9085600265333402 and parameters: {'min_child_samples': 5}. Best is trial 60 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:38,585] Trial 61 finished with value: 0.9085600265333402 and parameters: {'min_child_samples': 100}. Best is trial 60 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:38,925] Trial 62 finished with value: 0.9085600265333402 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:39,317] Trial 63 finished with value: 0.9085600265333402 and parameters: {'min_child_samples': 25}. Best is trial 60 with value: 0.9085600265333402.
# [I 2022-06-21 23:07:39,893] Trial 64 finished with value: 0.9085600265333402 and parameters: {'min_child_samples': 10}. Best is trial 60 with value: 0.9085600265333402.

# %% [markdown]
# After the optimization process we can extract the parameters for the Optuna study. The Optuna LightGBM integration is configured to tune the `lambda_l1`, `lambda_l2`, `num_leaves`, `feature_fraction`, `bagging_fraction` and `bagging_freq` parameters of the model using a Tree-structured Parzen Estimator (TPE) sampling algorithm. I set a fixed random seed for this process because the `TPESampler` is based on probabilistic models and therefore can produce different results for each study run (Akiba et al., 2019).

# %%
best_params = model_l2a.params
best_params
# Out:
# {'objective': 'regression',
#  'metric': 'l2',
#  'seed': 42,
#  'feature_pre_filter': False,
#  'lambda_l1': 3.3760383909096228,
#  'lambda_l2': 1.4786066213553811e-08,
#  'num_leaves': 143,
#  'feature_fraction': 1.0,
#  'bagging_fraction': 0.8391963650875751,
#  'bagging_freq': 5,
#  'min_child_samples': 20,
#  'num_iterations': 1000,
#  'early_stopping_round': None}

# %% [markdown]
# As we are estimating pixel values for a bathymetry map we can generate estimates for the whole map to visualize the model output. In the below cell we retrieve all valid explanatory data to produce a completely estimated map. While the result is still far grainier than the base-truth bathymetry map we can see a picture that is closer to the characteristic structures than when using the Stumpf Log-Ratio model.

# %%
X_all, y_all = get_X_y_for_split(
    train_test_eop,
    split_type=SplitType.All,
    data_feature=(FeatureType.DATA, 'L2A_data'),
    label_feature=(FeatureType.DATA_TIMELESS, 'bathy_data'),
)

l2a_sdb_estimation_values, l2a_sdb_estimation_map = create_sdb_estimation(train_test_eop, model_l2a, X_all)
eolx.visualization.plot_ndarray_band(l2a_sdb_estimation_map, cmap='viridis')
plt.show()

# %% [markdown]
# Looking at the map of deviations between estimates and true values we can see a similar picture as we do in the Stumpf example with the difference tha the spatial distribution of certain deviations appears much more diffuse.

# %%
masked_bathy_data = get_masked_map(
    train_test_eop,
    (FeatureType.DATA_TIMELESS, 'bathy_data'),
    data_mask_feature
)
l2a_sdb_errors = l2a_sdb_estimation_map - masked_bathy_data
eolx.visualization.plot_ndarray_band(l2a_sdb_errors, cmap='magma')
plt.show()

# %% [markdown]
# From the distribution of residuals we can see a narrower, more symmetric picture than we would in the Stumpf example. We can also observe that the distribution appears to be denser in the region of smaller deviations.

# %%
fig, ax = plt.subplots(figsize=(8, 6))
l2a_sdb_residuals = l2a_sdb_estimation_values - y_all
sns.histplot(l2a_sdb_residuals, binwidth=0.1, stat='density', ax=ax)
plt.show()

# %% [markdown]
# One of the more obvious drawbacks of using a tuned LightGBM model is that it is harder to reason about it. The regression metrics show impressive improvements over the Stumpf model but in contrast to a linear regression which can be easily interpreted and statistically tested for validity we have to use other methods for further inspection. At the end of this notebook I will use the dalex framework (Baniecki et al., 2021) for a brief exploration. I take a random subsample of 100,000 observations from the test set to make the this exploration more efficient for visualizations where all residuals would be visualized.

# %%
X_test, y_test = get_X_y_for_split(
    train_test_eop,
    split_type=SplitType.Test,
    data_feature=(FeatureType.DATA, 'L2A_data'),
    label_feature=(FeatureType.DATA_TIMELESS, 'bathy_data'),
)

X_test_subsample, _, y_test_subsample, _ = train_test_split(X_test, y_test, train_size=100000, random_state=42)
exp_lgbm_l2a = dx.Explainer(model_l2a, X_test_subsample, y_test_subsample, label='lgbm_tuned_l2a', verbose=False)
exp_lgbm_l2a.model_performance()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mse</th>
#       <th>rmse</th>
#       <th>r2</th>
#       <th>mae</th>
#       <th>mad</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>lgbm_tuned_l2a</th>
#       <td>0.908718</td>
#       <td>0.953267</td>
#       <td>0.845095</td>
#       <td>0.697233</td>
#       <td>0.525471</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Performing SDB on the Basis of L1C Data
#
# After performing the analysis on the basis of the L2A dataset we can now tune a model on the basis of the alternative data extracted from the L1C product. As the process remains mostly the same with the difference that we are using a different set of values for the training data set I will omit the explanation of the details as well as the discussion of the results until we reach the comparative evaluation.

# %%
# retrieve L1C training and validation data sets
(train_ds, val_ds) = create_train_val_set(train_test_eop, (FeatureType.DATA, 'L1C_data'))

# tune lgbm model for L1C data
with io.capture_output() as capture:
    model_l1c = lgb.train(
        params,
        train_ds,
        valid_sets=val_ds,
        callbacks=[log_evaluation(100), early_stopping(100)],
        optuna_seed=42,
    )

write_optuna_capture_to_logs('../optuna_logs', capture)

# retrieve L1C complete input and label data
X_all, y_all = get_X_y_for_split(
    train_test_eop,
    split_type=SplitType.All,
    data_feature=(FeatureType.DATA, 'L1C_data'),
    label_feature=(FeatureType.DATA_TIMELESS, 'bathy_data'),
)

# estimate L1C SDB values for complete data set
l1c_sdb_estimation_values, _ = create_sdb_estimation(train_test_eop, model_l1c, X_all)

# compute residuals for complete data set
l1c_sdb_residuals = l1c_sdb_estimation_values - y_all

# prepare explainer for L1C model on a subsample of the test set
X_test, y_test = get_X_y_for_split(
    train_test_eop,
    split_type=SplitType.Test,
    data_feature=(FeatureType.DATA, 'L1C_data'),
    label_feature=(FeatureType.DATA_TIMELESS, 'bathy_data'),
)
X_test_subsample, _, y_test_subsample, _ = train_test_split(X_test, y_test, train_size=100000, random_state=42)
exp_lgbm_l1c = dx.Explainer(model_l1c, X_test_subsample, y_test_subsample, label='lgbm_tuned_l1c', verbose=False)
# Out:
# [I 2022-06-21 23:09:27,219] A new study created in memory with name: no-name-a19abe48-11fd-4ca7-bb6f-46cad48abddf
# [I 2022-06-21 23:09:27,465] Trial 0 finished with value: 0.8554323852680519 and parameters: {'feature_fraction': 0.7}. Best is trial 0 with value: 0.8554323852680519.
# [I 2022-06-21 23:09:27,656] Trial 1 finished with value: 0.8554323852680519 and parameters: {'feature_fraction': 0.4}. Best is trial 0 with value: 0.8554323852680519.
# [I 2022-06-21 23:09:27,831] Trial 2 finished with value: 0.8440949152078981 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 2 with value: 0.8440949152078981.
# [I 2022-06-21 23:09:28,005] Trial 3 finished with value: 0.8341620378859295 and parameters: {'feature_fraction': 1.0}. Best is trial 3 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:28,229] Trial 4 finished with value: 0.8341620378859295 and parameters: {'feature_fraction': 0.5}. Best is trial 3 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:28,389] Trial 5 finished with value: 0.8341620378859295 and parameters: {'feature_fraction': 0.6}. Best is trial 3 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:28,566] Trial 6 finished with value: 0.8341620378859295 and parameters: {'feature_fraction': 0.8}. Best is trial 3 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:28,954] Trial 7 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 97}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:29,562] Trial 8 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 244}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:30,249] Trial 9 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 188}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:30,989] Trial 10 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 154}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:31,232] Trial 11 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 41}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:31,478] Trial 12 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 41}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:31,607] Trial 13 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 16}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:32,413] Trial 14 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 222}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:33,064] Trial 15 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 155}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:33,751] Trial 16 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 182}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:34,215] Trial 17 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 97}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:34,671] Trial 18 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 101}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:35,457] Trial 19 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 249}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:35,899] Trial 20 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 90}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:36,567] Trial 21 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 128}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:37,223] Trial 22 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 221}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:37,522] Trial 23 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 67}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:38,150] Trial 24 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 122}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:38,779] Trial 25 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 207}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:39,086] Trial 26 finished with value: 0.8341620378859295 and parameters: {'num_leaves': 61}. Best is trial 7 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:39,279] Trial 27 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.624724071308792, 'bagging_freq': 7}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:39,514] Trial 28 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.8391963650875751, 'bagging_freq': 5}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:39,703] Trial 29 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.49361118426561795, 'bagging_freq': 2}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:39,896] Trial 30 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.4348501673009778, 'bagging_freq': 7}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:40,108] Trial 31 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.7606690070465265, 'bagging_freq': 5}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:40,309] Trial 32 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.41235069657750206, 'bagging_freq': 7}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:40,552] Trial 33 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.8994655844810855, 'bagging_freq': 2}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:40,747] Trial 34 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.5090949803244422, 'bagging_freq': 2}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:40,970] Trial 35 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.5825453457760269, 'bagging_freq': 4}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:41,165] Trial 36 finished with value: 0.8341620378859295 and parameters: {'bagging_fraction': 0.6591670111857015, 'bagging_freq': 3}. Best is trial 27 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:41,399] Trial 37 finished with value: 0.8341620378859295 and parameters: {'feature_fraction': 0.9520000000000001}. Best is trial 37 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:41,627] Trial 38 finished with value: 0.8341620378859295 and parameters: {'feature_fraction': 0.9840000000000001}. Best is trial 37 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:41,819] Trial 39 finished with value: 0.8341620378859295 and parameters: {'feature_fraction': 0.92}. Best is trial 37 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:42,021] Trial 40 finished with value: 0.8341620378859295 and parameters: {'lambda_l1': 2.348881295853308e-05, 'lambda_l2': 3.6010467344475403}. Best is trial 40 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:42,225] Trial 41 finished with value: 0.8341620378859295 and parameters: {'lambda_l1': 0.038720902953704193, 'lambda_l2': 0.0024430162614261413}. Best is trial 40 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:42,411] Trial 42 finished with value: 0.8341620378859295 and parameters: {'lambda_l1': 2.5361081166471375e-07, 'lambda_l2': 2.5348407664333426e-07}. Best is trial 40 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:42,611] Trial 43 finished with value: 0.8341620378859295 and parameters: {'lambda_l1': 3.3323645788192616e-08, 'lambda_l2': 0.6245760287469893}. Best is trial 40 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:42,809] Trial 44 finished with value: 0.8341620378859295 and parameters: {'lambda_l1': 0.002570603566117598, 'lambda_l2': 0.023585940584142682}. Best is trial 40 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:43,018] Trial 45 finished with value: 0.8341620378859295 and parameters: {'lambda_l1': 1.5320059381854043e-08, 'lambda_l2': 5.360294728728285}. Best is trial 40 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:43,256] Trial 46 finished with value: 0.8341620378859295 and parameters: {'lambda_l1': 0.31044435499483225, 'lambda_l2': 8.148018307012941e-07}. Best is trial 40 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:43,446] Trial 47 finished with value: 0.8341620378859295 and parameters: {'lambda_l1': 4.329370014459266e-07, 'lambda_l2': 4.4734294104626844e-07}. Best is trial 40 with value: 0.8341620378859295.
# [I 2022-06-21 23:09:43,646] Trial 48 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 5.472429642032198e-06, 'lambda_l2': 0.00052821153945323}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:43,835] Trial 49 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 7.71800699380605e-05, 'lambda_l2': 4.17890272377219e-06}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:44,024] Trial 50 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 6.340273805264716e-06, 'lambda_l2': 3.299511607801006e-05}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:44,312] Trial 51 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 0.00029938550304646646, 'lambda_l2': 6.320114415891284e-05}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:44,517] Trial 52 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 5.397796156938148e-05, 'lambda_l2': 1.243964243043557e-05}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:44,731] Trial 53 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 0.0021766098008644303, 'lambda_l2': 0.0011769648243667595}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:44,942] Trial 54 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 1.988602691193548e-06, 'lambda_l2': 1.2808886981851321e-08}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:45,120] Trial 55 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 5.103027507670196, 'lambda_l2': 0.018810618912109483}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:45,361] Trial 56 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 0.00014491097476109757, 'lambda_l2': 4.2672313552671575e-06}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:45,553] Trial 57 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 1.941442519249988e-06, 'lambda_l2': 1.5145973415748907e-08}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:45,738] Trial 58 finished with value: 0.8341618231213076 and parameters: {'lambda_l1': 8.29015878325373, 'lambda_l2': 0.06076638194380435}. Best is trial 48 with value: 0.8341618231213076.
# [I 2022-06-21 23:09:45,977] Trial 59 finished with value: 0.8333903216024353 and parameters: {'lambda_l1': 0.0004981428194886922, 'lambda_l2': 3.6101822810432298e-06}. Best is trial 59 with value: 0.8333903216024353.
# [I 2022-06-21 23:09:46,203] Trial 60 finished with value: 0.8333903216024353 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 0.8333903216024353.
# [I 2022-06-21 23:09:46,428] Trial 61 finished with value: 0.8333903216024353 and parameters: {'min_child_samples': 10}. Best is trial 60 with value: 0.8333903216024353.
# [I 2022-06-21 23:09:46,621] Trial 62 finished with value: 0.8333903216024353 and parameters: {'min_child_samples': 5}. Best is trial 60 with value: 0.8333903216024353.
# [I 2022-06-21 23:09:46,840] Trial 63 finished with value: 0.8333903216024353 and parameters: {'min_child_samples': 100}. Best is trial 60 with value: 0.8333903216024353.
# [I 2022-06-21 23:09:47,055] Trial 64 finished with value: 0.8333903216024353 and parameters: {'min_child_samples': 25}. Best is trial 60 with value: 0.8333903216024353.

# %% [markdown]
# ## Performing SDB on the Basis of Acolite Data
#
# After performing the analysis on the basis of the L2A and L1C datasets we can now tune a model on the basis of the alternative data extracted from the Acolite product. As the process remains mostly the same with the difference that we are using a different set of values for the training data set I will omit the explanation of the details as well as the discussion of the results until we reach the comparative evaluation.

# %%
# retrieve Acolite training and validation data sets
(train_ds, val_ds) = create_train_val_set(train_test_eop, (FeatureType.DATA, 'L2R_data'))

# tune lgbm model for Acolite data
with io.capture_output() as capture:
    model_acolite = lgb.train(
        params,
        train_ds,
        valid_sets=val_ds,
        callbacks=[log_evaluation(100), early_stopping(100)],
        optuna_seed=42,
    )

write_optuna_capture_to_logs('../optuna_logs', capture)

# retrieve Acolite complete input and label data
X_all, y_all = get_X_y_for_split(
    train_test_eop,
    split_type=SplitType.All,
    data_feature=(FeatureType.DATA, 'L2R_data'),
    label_feature=(FeatureType.DATA_TIMELESS, 'bathy_data'),
)

# estimate Acolite SDB values for complete data set
acolite_sdb_estimation_values, _ = create_sdb_estimation(train_test_eop, model_acolite, X_all)

# compute residuals for complete data set
acolite_sdb_residuals = acolite_sdb_estimation_values - y_all

# prepare explainer for Acolite model on a subsample of the test set
X_test, y_test = get_X_y_for_split(
    train_test_eop,
    split_type=SplitType.Test,
    data_feature=(FeatureType.DATA, 'L2R_data'),
    label_feature=(FeatureType.DATA_TIMELESS, 'bathy_data'),
)
X_test_subsample, _, y_test_subsample, _ = train_test_split(X_test, y_test, train_size=100000, random_state=42)
exp_lgbm_acolite = dx.Explainer(model_acolite, X_test_subsample, y_test_subsample, label='lgbm_tuned_acolite', verbose=False)
# Out:
# [I 2022-06-21 23:11:14,802] A new study created in memory with name: no-name-9b027419-6fb1-4fd9-89c2-9173ed455a88
# [I 2022-06-21 23:11:15,057] Trial 0 finished with value: 1.264563480068905 and parameters: {'feature_fraction': 0.5}. Best is trial 0 with value: 1.264563480068905.
# [I 2022-06-21 23:11:15,225] Trial 1 finished with value: 1.2565280818955977 and parameters: {'feature_fraction': 0.6}. Best is trial 1 with value: 1.2565280818955977.
# [I 2022-06-21 23:11:15,400] Trial 2 finished with value: 1.2285483918644657 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 2 with value: 1.2285483918644657.
# [I 2022-06-21 23:11:15,575] Trial 3 finished with value: 1.2000004418635672 and parameters: {'feature_fraction': 1.0}. Best is trial 3 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:15,742] Trial 4 finished with value: 1.2000004418635672 and parameters: {'feature_fraction': 0.8}. Best is trial 3 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:15,958] Trial 5 finished with value: 1.2000004418635672 and parameters: {'feature_fraction': 0.4}. Best is trial 3 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:16,127] Trial 6 finished with value: 1.2000004418635672 and parameters: {'feature_fraction': 0.7}. Best is trial 3 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:16,667] Trial 7 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 97}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:17,444] Trial 8 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 244}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:18,220] Trial 9 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 188}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:18,909] Trial 10 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 154}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:19,128] Trial 11 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 41}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:19,404] Trial 12 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 41}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:19,539] Trial 13 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 16}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:20,270] Trial 14 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 222}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:20,921] Trial 15 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 155}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:21,677] Trial 16 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 182}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:22,135] Trial 17 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 97}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:22,670] Trial 18 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 101}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:23,340] Trial 19 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 249}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:23,738] Trial 20 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 90}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:24,274] Trial 21 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 128}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:25,014] Trial 22 finished with value: 1.2000004418635672 and parameters: {'num_leaves': 221}. Best is trial 7 with value: 1.2000004418635672.
# [I 2022-06-21 23:11:25,280] Trial 23 finished with value: 1.1990686355621167 and parameters: {'num_leaves': 67}. Best is trial 23 with value: 1.1990686355621167.
# [I 2022-06-21 23:11:25,535] Trial 24 finished with value: 1.1990686355621167 and parameters: {'num_leaves': 64}. Best is trial 23 with value: 1.1990686355621167.
# [I 2022-06-21 23:11:25,765] Trial 25 finished with value: 1.1990686355621167 and parameters: {'num_leaves': 59}. Best is trial 23 with value: 1.1990686355621167.
# [I 2022-06-21 23:11:25,822] Trial 26 finished with value: 1.1990686355621167 and parameters: {'num_leaves': 4}. Best is trial 23 with value: 1.1990686355621167.
# [I 2022-06-21 23:11:26,099] Trial 27 finished with value: 1.1990686355621167 and parameters: {'bagging_fraction': 0.624724071308792, 'bagging_freq': 7}. Best is trial 27 with value: 1.1990686355621167.
# [I 2022-06-21 23:11:26,393] Trial 28 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.8391963650875751, 'bagging_freq': 5}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:26,630] Trial 29 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.49361118426561795, 'bagging_freq': 2}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:26,874] Trial 30 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.4348501673009778, 'bagging_freq': 7}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:27,147] Trial 31 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.7606690070465265, 'bagging_freq': 5}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:27,371] Trial 32 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.41235069657750206, 'bagging_freq': 7}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:27,845] Trial 33 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.8994655844810855, 'bagging_freq': 2}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:28,189] Trial 34 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.5090949803244422, 'bagging_freq': 2}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:28,553] Trial 35 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.5825453457760269, 'bagging_freq': 4}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:28,842] Trial 36 finished with value: 1.1927009506148996 and parameters: {'bagging_fraction': 0.6591670111857015, 'bagging_freq': 3}. Best is trial 28 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:29,170] Trial 37 finished with value: 1.1927009506148996 and parameters: {'feature_fraction': 0.9520000000000001}. Best is trial 37 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:29,427] Trial 38 finished with value: 1.1927009506148996 and parameters: {'feature_fraction': 0.9840000000000001}. Best is trial 37 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:29,691] Trial 39 finished with value: 1.1927009506148996 and parameters: {'feature_fraction': 0.92}. Best is trial 37 with value: 1.1927009506148996.
# [I 2022-06-21 23:11:30,003] Trial 40 finished with value: 1.1886036522865926 and parameters: {'lambda_l1': 2.348881295853308e-05, 'lambda_l2': 3.6010467344475403}. Best is trial 40 with value: 1.1886036522865926.
# [I 2022-06-21 23:11:30,310] Trial 41 finished with value: 1.1886036522865926 and parameters: {'lambda_l1': 0.038720902953704193, 'lambda_l2': 0.0024430162614261413}. Best is trial 40 with value: 1.1886036522865926.
# [I 2022-06-21 23:11:30,602] Trial 42 finished with value: 1.1886036522865926 and parameters: {'lambda_l1': 2.5361081166471375e-07, 'lambda_l2': 2.5348407664333426e-07}. Best is trial 40 with value: 1.1886036522865926.
# [I 2022-06-21 23:11:30,907] Trial 43 finished with value: 1.1886036522865926 and parameters: {'lambda_l1': 3.3323645788192616e-08, 'lambda_l2': 0.6245760287469893}. Best is trial 40 with value: 1.1886036522865926.
# [I 2022-06-21 23:11:31,196] Trial 44 finished with value: 1.1886036522865926 and parameters: {'lambda_l1': 0.002570603566117598, 'lambda_l2': 0.023585940584142682}. Best is trial 40 with value: 1.1886036522865926.
# [I 2022-06-21 23:11:31,517] Trial 45 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 1.5320059381854043e-08, 'lambda_l2': 5.360294728728285}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:31,885] Trial 46 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 0.31044435499483225, 'lambda_l2': 8.148018307012941e-07}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:32,208] Trial 47 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 4.329370014459266e-07, 'lambda_l2': 4.4734294104626844e-07}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:32,524] Trial 48 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 5.472429642032198e-06, 'lambda_l2': 0.00052821153945323}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:32,920] Trial 49 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 7.71800699380605e-05, 'lambda_l2': 4.17890272377219e-06}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:33,231] Trial 50 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 3.207959657544482, 'lambda_l2': 0.08430920984585018}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:33,536] Trial 51 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 5.319049072944658, 'lambda_l2': 1.2787005110682527e-08}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:33,868] Trial 52 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 0.027322882204042016, 'lambda_l2': 1.243964243043557e-05}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:34,201] Trial 53 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 0.15412667882547773, 'lambda_l2': 4.8858959969507036e-05}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:34,541] Trial 54 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 0.0011301051806847315, 'lambda_l2': 1.184178882320982e-08}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:34,883] Trial 55 finished with value: 1.187751229618849 and parameters: {'lambda_l1': 0.32409116037260344, 'lambda_l2': 0.0040683669660024025}. Best is trial 45 with value: 1.187751229618849.
# [I 2022-06-21 23:11:35,239] Trial 56 finished with value: 1.1819644259688145 and parameters: {'lambda_l1': 1.6262914459106085e-08, 'lambda_l2': 8.463520869408649}. Best is trial 56 with value: 1.1819644259688145.
# [I 2022-06-21 23:11:35,609] Trial 57 finished with value: 1.1819644259688145 and parameters: {'lambda_l1': 0.00141343323169811, 'lambda_l2': 4.267979802035024e-08}. Best is trial 56 with value: 1.1819644259688145.
# [I 2022-06-21 23:11:35,968] Trial 58 finished with value: 1.1819644259688145 and parameters: {'lambda_l1': 3.3777238831941368e-06, 'lambda_l2': 7.678768449680499e-05}. Best is trial 56 with value: 1.1819644259688145.
# [I 2022-06-21 23:11:36,327] Trial 59 finished with value: 1.1819644259688145 and parameters: {'lambda_l1': 9.379463801182402e-07, 'lambda_l2': 0.00024212213929448697}. Best is trial 56 with value: 1.1819644259688145.
# [I 2022-06-21 23:11:36,634] Trial 60 finished with value: 1.1819644259688145 and parameters: {'min_child_samples': 50}. Best is trial 60 with value: 1.1819644259688145.
# [I 2022-06-21 23:11:37,033] Trial 61 finished with value: 1.1819644259688145 and parameters: {'min_child_samples': 5}. Best is trial 60 with value: 1.1819644259688145.
# [I 2022-06-21 23:11:37,408] Trial 62 finished with value: 1.1819644259688145 and parameters: {'min_child_samples': 25}. Best is trial 60 with value: 1.1819644259688145.
# [I 2022-06-21 23:11:37,772] Trial 63 finished with value: 1.1819644259688145 and parameters: {'min_child_samples': 10}. Best is trial 60 with value: 1.1819644259688145.
# [I 2022-06-21 23:11:37,971] Trial 64 finished with value: 1.1819644259688145 and parameters: {'min_child_samples': 100}. Best is trial 60 with value: 1.1819644259688145.

# %% [markdown]
# ## Evaluation of SDB Results
#
# Looking at the raw performance metrics we see that all models are relatively close together with the L1C and L2A based models having an advantage over the Acolite based one.

# %%
exp_list = [exp_lgbm_l1c, exp_lgbm_l2a, exp_lgbm_acolite]
pd.concat([exp.model_performance().result for exp in exp_list])
# Out:
#                          mse      rmse        r2       mae       mad
# lgbm_tuned_l1c      0.829186  0.910596  0.858653  0.668370  0.512383
# lgbm_tuned_l2a      0.908718  0.953267  0.845095  0.697233  0.525471
# lgbm_tuned_acolite  1.208524  1.099329  0.793989  0.797575  0.594203

# %% [markdown]
# Overlaying the residuals confirms this notion.

# %%
residuals_df = pd.DataFrame({
    'l1c': l1c_sdb_residuals,
    'l2a': l2a_sdb_residuals,
    'acolite': acolite_sdb_residuals
})

plt.figure(figsize=(10, 6))
sns.histplot(residuals_df, binwidth=0.1, stat='density', element='step', common_norm=False)
plt.show()

# %% [markdown]
# An alternative perspective on the global performance of the models with respect to the reverse cumulative distribution of the absolute residuals. With this visualization it becomes even more visible that the L1C and L2A based models are very close in regards to their residual distributions.

# %%
fig = exp_list[0].model_performance().plot([exp.model_performance() for exp in exp_list[1:]], show=False)
fig.write_image('../figures/plotly_exports/10__rev_cum_dist_res.png', format='png', engine='orca')

# %% [markdown]
# ![reverse cumulative distribution of absolute residuals](../figures/plotly_exports/10__rev_cum_dist_res.png)

# %% [markdown]
# In the Stumpf Log-Ratio model we know exactly that we are either looking at the red and blue or green and blue bands to come to a bathymetry estimate. The exact mathematical relationship can be inferred by extracting the $m_0$ and $m_1$ parameters and inspecting the resulting function. With large ensemble models based on gradient boosted trees we could theoretically also inspect each tree, each split and each weight but this hardly leads to the same intuition.
#
# With dalex we can inspect the importance each variable has for coming to an estimate in relation to all other variables. For this AOI we can see that variables with the index values 2 and 1 (corresponding with the green and blue bands respectively) have the greatest influence on the estimate. This behavior follows the empirical intuition from the Stumpf model which could indicate that we have calibrated a valid model for the Puerto Rico AOI.

# %%
fig = exp_list[0].model_parts().plot([exp.model_parts() for exp in exp_list[1:]], show=False)
fig.write_image('../figures/plotly_exports/10__variable_importance.png', format='png', engine='orca')

# %% [markdown]
# ![variable importance](../figures/plotly_exports/10__variable_importance.png)

# %% [markdown]
# Because those two bands have the greatest impact on the bathymetry estimate it makes sense to look at their respective partial dependence plots. In those we can see, that the different models show similar responses for the green and blue bands with the L1C band being shifted by a certain difference in reflectance. This makes sense because both the L2A and Acolite models where trained on data that was produced by applying atmospheric correction. When preparing the dataset we looked at the histograms of the red, green and blue bands where this shift was also clearly visible.

# %%
fig = exp_list[0].model_profile(variable_splits_type="quantiles").plot(
    [exp.model_profile(variable_splits_type="quantiles") for exp in exp_list[1:]],
    variables=['2', '1'],
    title="Partial Dependence",
    show=False,
)
fig.write_image('../figures/plotly_exports/10__partial_dependence.png', format='png', engine='orca', width=800)
# Out:
# Calculating ceteris paribus: 100%|██████████| 13/13 [00:00<00:00, 22.69it/s]
# Calculating ceteris paribus: 100%|██████████| 12/12 [00:00<00:00, 19.93it/s]
# Calculating ceteris paribus: 100%|██████████| 11/11 [00:00<00:00, 18.58it/s]

# %% [markdown]
# ![partial dependence plot](../figures/plotly_exports/10__partial_dependence.png)
